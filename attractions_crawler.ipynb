# %%
import requests
import lxml.html as lh
import pandas as pd
import re

# %%
# downloading and saving canada tours and tickets page
def scrape(url):
    page = requests.get(url)
    html = page.content
    open('htmlpages/canada_tours.txt','wb').write(html)
    categories()

# %%
# get categories of tours and corresponding links
def categories():
    html = open('htmlpages/canada_tours.txt','r').read()
    tree = lh.fromstring(html)
    cat = tree.xpath('//div[@class="filter_list_0"]')[0]
    tour_categories = cat.xpath('./div/label/a/text()')
    category_links = cat.xpath('./div/label/a/@href')
    if cat.xpath('./div[@class="collapse hidden"]'):
        tour_categories += cat.xpath('./div[@class="collapse hidden"]/div/label/a/text()')
        category_links += cat.xpath('./div[@class="collapse hidden"]/div/label/a/@href')
    category_links = [base_page+x for x in category_links]
    tour_categories = ['_'.join(x.split(' ')[:-1]).lower() for x in tour_categories]
    attraction = list()
    attraction_category = list()
    for i in range(len(tour_categories)):
        print(tour_categories[i])
        print(category_links[i])
        page = requests.get(category_links[i])
        open("htmlpages/"+tour_categories[i]+".txt",'wb').write(page.content)
        output = get_tours(tour_categories[i])
        print(len(output))
        attraction += output
        attraction_category += [tour_categories[i] for x in range(len(output))]
    df = pd.DataFrame({'attraction': attraction,'category': attraction_category})
    df.to_json('outputs/attractions_cat.json',orient='records',index=True)

# %%
def get_tours(tour_category):
    html = open("htmlpages/"+tour_category+".txt",'r',encoding='utf-8').read()
    tree = lh.fromstring(html)
    
    attractions = tree.xpath('//div[@class="listing attraction_element"]//div[@class="listing_title"]/a/@onclick')    
    attractions = [base_page+attraction.split(';')[-2].split(',')[2][2:-1] for attraction in attractions]
   
    next_attractions = list()
    if tree.xpath("//div[@class='unified pagination ']"):
        next_page_container = tree.xpath("//div[@class='unified pagination ']")[0]
        if next_page_container.xpath("./span/@class") != ["nav next disabled"]:
            next_page = base_page+next_page_container.xpath("./a[@class='nav next rndBtn ui_button primary taLnk']/@href")[0]
            page_no = next_page_container.xpath("./a[@class='nav next rndBtn ui_button primary taLnk']/@data-page-number")[0]
            page = requests.get(next_page)
            if bool(re.search(r'\d',tour_category)):
                file_name = re.sub(r'\d+','',tour_category)+str(page_no)
            else:
                file_name = tour_category+str(page_no)
            open("htmlpages/"+file_name+".txt",'wb').write(page.content)
            next_attractions = get_tours(file_name)
    
    if len(next_attractions) != 0:
        attractions += next_attractions
    
    return attractions

# %%
base_page = "https://tripadvisor.ca"
scrape('https://www.tripadvisor.ca/Attraction_Products-g153339-Canada.html')
# Out:
# featured_tours_and_tickets
# https://tripadvisor.ca/Attraction_Products-g153339-zfg12131-Canada.html
# 8
# local_experiences
# https://tripadvisor.ca/Attraction_Products-g153339-zfg16473-Canada.html
# 3
# air,_helicopter_&_balloon_tours
# https://tripadvisor.ca/Attraction_Products-g153339-zfg11864-Canada.html
# 58
# cruises,_sailing_&_water_tours
# https://tripadvisor.ca/Attraction_Products-g153339-zfg11865-Canada.html
# 144
# cultural_&_theme_tours
# https://tripadvisor.ca/Attraction_Products-g153339-zfg11866-Canada.html
# 192
# day_trips_&_excursions
# https://tripadvisor.ca/Attraction_Products-g153339-zfg11867-Canada.html
# 160
# food,_wine_&_nightlife
# https://tripadvisor.ca/Attraction_Products-g153339-zfg11868-Canada.html
# 268
# holiday_&_seasonal_tours
# https://tripadvisor.ca/Attraction_Products-g153339-zfg11869-Canada.html
# 24
# sightseeing_tickets_&_passes
# https://tripadvisor.ca/Attraction_Products-g153339-zfg11870-Canada.html
# 88
# outdoor_activities
# https://tripadvisor.ca/Attraction_Products-g153339-zfg12022-Canada.html
# 337
# shopping_&_fashion
# https://tripadvisor.ca/Attraction_Products-g153339-zfg11871-Canada.html
# 5
# shows,_concerts_&_sports
# https://tripadvisor.ca/Attraction_Products-g153339-zfg11872-Canada.html
# 14
# tours_&_sightseeing
# https://tripadvisor.ca/Attraction_Products-g153339-zfg11873-Canada.html
# 462
# theme_parks
# https://tripadvisor.ca/Attraction_Products-g153339-zfg11874-Canada.html
# 7
# transfers_&_ground_transport
# https://tripadvisor.ca/Attraction_Products-g153339-zfg11875-Canada.html
# 138
# walking_&_biking_tours
# https://tripadvisor.ca/Attraction_Products-g153339-zfg11876-Canada.html
# 176
# water_sports
# https://tripadvisor.ca/Attraction_Products-g153339-zfg12023-Canada.html
# 153
# weddings_&_honeymoons
# https://tripadvisor.ca/Attraction_Products-g153339-zfg11877-Canada.html
# 2
# family_friendly
# https://tripadvisor.ca/Attraction_Products-g153339-zfg11879-Canada.html
# 222
# shore_excursions
# https://tripadvisor.ca/Attraction_Products-g153339-zfg11880-Canada.html
# 58
# multi-day_&_extended_tours
# https://tripadvisor.ca/Attraction_Products-g153339-zfg11878-Canada.html
# 80
# luxury_&_special_occasions
# https://tripadvisor.ca/Attraction_Products-g153339-zfg11881-Canada.html
# 112
# private_&_custom_tours
# https://tripadvisor.ca/Attraction_Products-g153339-zfg11882-Canada.html
# 561
# viator_vip_&_exclusive_tours
# https://tripadvisor.ca/Attraction_Products-g153339-zfg11883-Canada.html
# 1
# spa_tours
# https://tripadvisor.ca/Attraction_Products-g153339-zfg11884-Canada.html
# 0
# classes_&_workshops
# https://tripadvisor.ca/Attraction_Products-g153339-zfg12024-Canada.html
# 10
# recommended_experiences
# https://tripadvisor.ca/Attraction_Products-g153339-zfg17447-Canada.html
# 375
