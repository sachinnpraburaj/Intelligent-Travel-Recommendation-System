# %%
import ipywidgets as widgets
from ipywidgets import HBox, VBox
from ipywidgets import Layout

# %%
# we can do this till recommendation is getting listed! to keep the UI engaging!
widgets.FloatProgress(
    value=7.5,
    min=0,
    max=10.0,
    step=0.1,
    description='Loading:',
    bar_style='info',
    orientation='horizontal'
)

# b = widgets.Label()
# b.style.keys
# b1 = VBox()
# Out:
# ['_model_module',
#  '_model_module_version',
#  '_model_name',
#  '_view_count',
#  '_view_module',
#  '_view_module_version',
#  '_view_name',
#  'description_width']

# %%
# for attractions
days = 5
num_pages = []
num_eve = []
time = ['MORNING', 'EVENING']
fields = ['NAME', 'CATEGORY', 'LOCATION', 'PRICE', 'RATING']
tab = []
recommendations = ['Recommendation 1:', 'Recommendation 2:']

box_layout = Layout(justify_content='space-between',
                    display='flex',
                    flex_flow='row', 
                    align_items='stretch',
                   )
column_layout = Layout(justify_content='space-between',
                    width='75%',
                    display='flex',
                    flex_flow='column', 
                   )


for i in range(days):
    file = open("image.png", "rb")
    image = file.read()
    
    tab.append(VBox(children=
                    [HBox(children=
                          [VBox(children=
                                [widgets.HTML(value = f"<b><font color='orange'>{time[0]}</b>"),
                                 widgets.HTML(value = f"<b><font color='purple'>{recommendations[0]}</b>"),
                                 widgets.Image(value=image, format='png', width=300, height=400), 
                                 widgets.Text(description=fields[0], value='put value here', disabled=True), 
                                 widgets.Text(description=fields[1], value='put value here', disabled=True),
                                 widgets.Text(description=fields[2], value='put value here', disabled=True), 
                                 widgets.Text(description=fields[3], value='put value here', disabled=True), 
                                 widgets.Text(description=fields[4], value='put value here', disabled=True)
                                ], layout=column_layout), 
                            VBox(children=
                                [widgets.HTML(value = f"<b><font color='orange'>{time[1]}</b>"), 
                                 widgets.HTML(value = f"<b><font color='purple'>{recommendations[0]}</b>"),
                                 widgets.Image(value=image, format='png', width=300, height=400), 
                                 widgets.Text(description=fields[0], value='put value here', disabled=True), 
                                 widgets.Text(description=fields[1], value='put value here', disabled=True),
                                 widgets.Text(description=fields[2], value='put value here', disabled=True), 
                                 widgets.Text(description=fields[3], value='put value here', disabled=True), 
                                 widgets.Text(description=fields[4], value='put value here', disabled=True)
                                ], layout=column_layout)
                          ], layout=box_layout),
                     
                     HBox(children=
                          [VBox(children=
                                [widgets.HTML(value = f"<b><font color='purple'>{recommendations[1]}</b>"),
                                 widgets.Image(value=image, format='png', width=300, height=400), 
                                 widgets.Text(description=fields[0], value='put value here', disabled=True), 
                                 widgets.Text(description=fields[1], value='put value here', disabled=True),
                                 widgets.Text(description=fields[2], value='put value here', disabled=True), 
                                 widgets.Text(description=fields[3], value='put value here', disabled=True), 
                                 widgets.Text(description=fields[4], value='put value here', disabled=True)
                                ], layout=column_layout), 
                            VBox(children=
                                [widgets.HTML(value = f"<b><font color='purple'>{recommendations[1]}</b>"),
                                 widgets.Image(value=image, format='png', width=300, height=400), 
                                 widgets.Text(description=fields[0], value='put value here', disabled=True), 
                                 widgets.Text(description=fields[1], value='put value here', disabled=True),
                                 widgets.Text(description=fields[2], value='put value here', disabled=True), 
                                 widgets.Text(description=fields[3], value='put value here', disabled=True), 
                                 widgets.Text(description=fields[4], value='put value here', disabled=True)
                                ], layout=column_layout),
                          ], layout=box_layout)
                    
                    ])
               )

    
    
tab_recomone = widgets.Tab(children=tab)
for i in range(len(children)):
    tab_recomone.set_title(i, str('Day '+ str(i)))
tab_recomone
    
# VBox(children=[tab_recomone, tab_recomtwo])
# Out:
# Tab(children=(VBox(children=(HBox(children=(VBox(children=(HTML(value="<b><font color='orange'>MORNING</b>"), …

# %%
# For restaurants//
days = 5
num_pages = []
num_eve = []
time = ['BREAKFAST', 'LUNCH', 'DINNER']
fields = ['NAME', 'CATEGORY', 'LOCATION', 'PRICE', 'RATING']
tab = []
tab2 = []

for i in range(days):
    file = open("image.png", "rb")
    image = file.read()
    
    tab.append(VBox(children=
                    [HBox(children=
                          [VBox(children=
                                [widgets.Text(value=time[0], disabled=True), 
                                 widgets.Image(value=image, format='png', width=300, height=400), 
                                 widgets.Text(description=fields[0], value='put value here', disabled=True), 
                                 widgets.Text(description=fields[1], value='put value here', disabled=True),
                                 widgets.Text(description=fields[2], value='put value here', disabled=True), 
                                 widgets.Text(description=fields[3], value='put value here', disabled=True), 
                                 widgets.Text(description=fields[4], value='put value here', disabled=True)
                                ]), 
                            VBox(children=
                                [widgets.Text(value=time[1], disabled=True), 
                                 widgets.Image(value=image, format='png', width=300, height=400), 
                                 widgets.Text(description=fields[0], value='put value here', disabled=True), 
                                 widgets.Text(description=fields[1], value='put value here', disabled=True),
                                 widgets.Text(description=fields[2], value='put value here', disabled=True), 
                                 widgets.Text(description=fields[3], value='put value here', disabled=True), 
                                 widgets.Text(description=fields[4], value='put value here', disabled=True)
                                ]),
                           VBox(children=
                                [widgets.Text(value=time[2], disabled=True), 
                                 widgets.Image(value=image, format='png', width=300, height=400), 
                                 widgets.Text(description=fields[0], value='put value here', disabled=True), 
                                 widgets.Text(description=fields[1], value='put value here', disabled=True),
                                 widgets.Text(description=fields[2], value='put value here', disabled=True), 
                                 widgets.Text(description=fields[3], value='put value here', disabled=True), 
                                 widgets.Text(description=fields[4], value='put value here', disabled=True)
                                ]),
                          ])
                    ])
               )

for i in range(days):
    file = open("image.png", "rb")
    image = file.read()
    
    tab2.append(VBox(children=
                    [HBox(children=
                          [VBox(children=
                                [widgets.Text(value=time[0], disabled=True), 
                                 widgets.Image(value=image, format='png', width=300, height=400), 
                                 widgets.Text(description=fields[0], value='put value here', disabled=True), 
                                 widgets.Text(description=fields[1], value='put value here', disabled=True),
                                 widgets.Text(description=fields[2], value='put value here', disabled=True), 
                                 widgets.Text(description=fields[3], value='put value here', disabled=True), 
                                 widgets.Text(description=fields[4], value='put value here', disabled=True)
                                ]), 
                            VBox(children=
                                [widgets.Text(value=time[1], disabled=True), 
                                 widgets.Image(value=image, format='png', width=300, height=400), 
                                 widgets.Text(description=fields[0], value='put value here', disabled=True), 
                                 widgets.Text(description=fields[1], value='put value here', disabled=True),
                                 widgets.Text(description=fields[2], value='put value here', disabled=True), 
                                 widgets.Text(description=fields[3], value='put value here', disabled=True), 
                                 widgets.Text(description=fields[4], value='put value here', disabled=True)
                                ]),
                           VBox(children=
                                [widgets.Text(value=time[2], disabled=True), 
                                 widgets.Image(value=image, format='png', width=300, height=400), 
                                 widgets.Text(description=fields[0], value='put value here', disabled=True), 
                                 widgets.Text(description=fields[1], value='put value here', disabled=True),
                                 widgets.Text(description=fields[2], value='put value here', disabled=True), 
                                 widgets.Text(description=fields[3], value='put value here', disabled=True), 
                                 widgets.Text(description=fields[4], value='put value here', disabled=True)
                                ]),
                          ])
                    ])
               )

tab_recomone = widgets.Tab(children=tab)
for i in range(len(children)):
    tab_recomone.set_title(i, str('Day '+ str(i)))

tab_recomtwo = widgets.Tab(children=tab2)
for i in range(len(children)):
    tab_recomtwo.set_title(i, str('Day '+ str(i)))
    
VBox(children=[tab_recomone, tab_recomtwo])
# Out:
# VBox(children=(Tab(children=(VBox(children=(HBox(children=(VBox(children=(Text(value='BREAKFAST', disabled=Tru…
